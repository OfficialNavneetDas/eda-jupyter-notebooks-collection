# %%
import pandas as pd

# %%
data=pd.read_excel("Sample - Superstore.xls")
print(f"sample:")
data.sample(5)
# Out:
# sample:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2144    2145  CA-2016-155481 2016-09-01 2016-09-05  Standard Class
# 8017    8018  US-2014-131870 2014-09-09 2014-09-11     First Class
# 7543    7544  US-2017-112347 2017-12-02 2017-12-06  Standard Class
# 8313    8314  CA-2014-161508 2014-07-12 2014-07-16  Standard Class
# 2570    2571  CA-2017-134404 2017-12-27 2017-12-27        Same Day
#
#      Customer ID    Customer Name      Segment        Country          City  \
# 2144    DK-13225        Dean Katz    Corporate  United States  Philadelphia
# 8017    NF-18595     Nicole Fjeld  Home Office  United States     Lancaster
# 7543    BS-11380     Bill Stewart    Corporate  United States        Denver
# 8313    PV-18985    Paul Van Hugh  Home Office  United States   League City
# 2570    DR-12880  Dan Reichenbach    Corporate  United States        Newark
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## step1 => Run "pip install pandas-profiling" to install profiling
# ## step2 => Run:
# ```python
# from pandas_profiling import ProfileReport
# prof =  ProfileReport(data)
# prof.to_file(output_file="SampleSuperstore_EDA.html")
# ```
# **it will create a html page with simple EDA for you**

# %%
# !pip install pandas-profiling

# %%
! python.exe -m pip install --upgrade pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.0/1.8 MB 3.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# ...

# %%
from pandas_profiling import ProfileReport
prof =  ProfileReport(data)
prof.to_file(output_file="SampleSuperstore_EDA.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof =  ProfileReport(data)
#       3 prof.to_file(output_file="SampleSuperstore_EDA.html")
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...

# %%
pip install ydata-profiling
# Out:
# ...
#
#   Attempting uninstall: typing_extensions
#
#     Found existing installation: typing_extensions 4.13.2
#
#     Uninstalling typing_extensions-4.13.2:
#
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
#    ---- ----------------------------------- 1/9 [typing_extensions]
# ...

# %%
from ydata_profiling import ProfileReport
prof =  ProfileReport(data)
prof.to_file(output_file="SampleSuperstore_EDA.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
